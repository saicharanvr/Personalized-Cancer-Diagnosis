# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics.classification import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score

warnings.filterwarnings("ignore")
from mlxtend.classifier import StackingClassifier
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression

from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training/training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the separator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
#text processing stage.
start_time = time.clock()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.clock() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 232.53088692405265 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sortlevel()
test_class_distribution = test_df['Class'].value_counts().sortlevel()
cv_class_distribution = cv_df['Class'].value_counts().sortlevel()

my_colors = 'rgbkymc'
train_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar')
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.536598785706848
# Log loss on Test Data using Random Model 2.501572555849742
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------

# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q1.</b> Gene, What type of feature it is ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Gene is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q2.</b> How many categories are there and How they are distributed?</p>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 239
# BRCA1     177
# EGFR       96
# TP53       96
# BRCA2      88
# PTEN       77
# KIT        68
# BRAF       58
# ERBB2      47
# ALK        44
# PDGFRA     42
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 239 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# <p style="font-size:18px;"> <b>Q3.</b> How to featurize this Gene feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>there are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_feature_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = TfidfVectorizer(max_features=1000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 1020      TSC2
# 591      SMAD4
# 640     CDKN1B
# 2057       MYC
# 597      SMAD4
# Name: Gene, dtype: object

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 238)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
warnings.filterwarnings("ignore")
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid" ,cv=3)
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.3629614677805755
# For values of alpha =  0.0001 The log loss is: 1.2289812801611668
# For values of alpha =  0.001 The log loss is: 1.2437457363923006
# For values of alpha =  0.01 The log loss is: 1.3674472401214413
# For values of alpha =  0.1 The log loss is: 1.4821606635545672
# For values of alpha =  1 The log loss is: 1.507280403053825
# For values of best alpha =  0.0001 The train log loss is: 1.0206123749999394
# For values of best alpha =  0.0001 The cross validation log loss is: 1.2289812801611668
# For values of best alpha =  0.0001 The test log loss is: 1.2370916165142418

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  229  genes in train dataset?
# Ans
# 1. In test data 643 out of 665 : 96.69172932330827
# 2. In cross validation data 514 out of  532 : 96.61654135338345

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1924
# Truncating_Mutations         59
# Deletion                     49
# Amplification                47
# Fusions                      23
# E17K                          3
# Overexpression                3
# Q22K                          2
# Promoter_Hypermethylation     2
# G13D                          2
# T73I                          2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1924 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.02777778 0.05084746 0.07297552 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = TfidfVectorizer(max_features=1000)
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 1000)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7229375973742576
# For values of alpha =  0.0001 The log loss is: 1.7138973681456389
# For values of alpha =  0.001 The log loss is: 1.7156025258108618
# For values of alpha =  0.01 The log loss is: 1.7253698357010507
# For values of alpha =  0.1 The log loss is: 1.7315268266891266
# For values of alpha =  1 The log loss is: 1.733560642137075
# For values of best alpha =  0.0001 The train log loss is: 1.2017189053272317
# For values of best alpha =  0.0001 The cross validation log loss is: 1.7138973681456389
# For values of best alpha =  0.0001 The test log loss is: 1.6706012725464994

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1924  genes in test and cross validation data sets?
# Ans
# 1. In test data 64 out of 665 : 9.624060150375941
# 2. In cross validation data 56 out of  532 : 10.526315789473683

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = TfidfVectorizer(min_df=3,max_features=1000)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({252.4001237044917: 1, 179.48528685162722: 1, 137.65728223996564: 1, 132.318275214261: 1, 129.86823401694724: 1, 118.83802744957643: 1, 117.98163395653633: 1, 115.00646835862715: 1, 110.57664642961733: 1, 110.22321102689644: 1, 105.92374267774878: 1, 87.90437321835212: 1, 87.77092985340478: 1, 87.10824978030715: 1, 81.03656633869873: 1, 78.89994254952184: 1, 78.40727737255371: 1, 78.08447208128239: 1, 77.8000966796823: 1, 77.25462095814834: 1, 76.67691671214187: 1, 75.21959794305205: 1, 71.27651598578028: 1, 69.01823555685876: 1, 68.91254474088232: 1, 67.37244842872985: 1, 67.16527880012147: 1, 64.95332989102462: 1, 63.89906590551239: 1, 63.7690147317071: 1, 63.41212262266746: 1, 63.34321522905685: 1, 63.12235704094563: 1, 60.16740632577167: 1, 58.81421080265518: 1, 56.748503696247575: 1, 55.99897298143774: 1, 53.869976486489854: 1, 51.1067080385123: 1, 50.7673149030178: 1, 50.38102513315939: 1, 49.45701778465801: 1, 48.82771473128169: 1, 48.13998302667363: 1, 46.18757717634412: 1, 46.149184260076936: 1, 45.86571211010914: 1, 45.06758963302028: 1, 44.72780195374166: 1, 44.44908322655721: 1, 43.68863412751298: 1, 43.595236944435456: 1, 43.37473978510479: 1, 43.290498991163695: 1, 43.14057412859981: 1, 42.15504285476687: 1, 42.12875484047736: 1, 41.97604166940602: 1, 41.92720963106333: 1, 41.618129315088595: 1, 41.54092233764095: 1, 40.772261842818246: 1, 40.54973203742436: 1, 40.51293737739145: 1, 40.457921693685975: 1, 40.13407476341787: 1, 39.8863716578193: 1, 39.83661505773622: 1, 38.61200846564469: 1, 37.6717606211704: 1, 37.61376191032496: 1, 37.57261244685067: 1, 37.55466650517508: 1, 37.52129680278094: 1, 37.295183793791104: 1, 36.707845760179666: 1, 36.45088165264746: 1, 35.30305835548031: 1, 35.29987016420352: 1, 35.24897185418973: 1, 35.23745572587065: 1, 34.942328767785966: 1, 34.91759873897259: 1, 34.78390768405989: 1, 34.575586161956224: 1, 34.36473757746113: 1, 33.92115349268629: 1, 33.90111472890254: 1, 33.81417439305587: 1, 33.76799230339443: 1, 33.69596438841807: 1, 33.42534010312986: 1, 33.33619949349902: 1, 32.83378197953264: 1, 32.82374751723201: 1, 32.336460468494785: 1, 32.33061188672689: 1, 32.11160981115836: 1, 31.990236269713908: 1, 31.92736698947115: 1, 31.88593201151005: 1, 31.879180161108874: 1, 31.748081219184005: 1, 31.670592188340432: 1, 31.389330312165168: 1, 31.36455580650914: 1, 31.357891749263786: 1, 31.008341075996466: 1, 30.837786113404523: 1, 30.728509953694747: 1, 30.49096436725831: 1, 30.444722532653195: 1, 30.399895096975584: 1, 30.38014069941863: 1, 30.37948871054211: 1, 30.26244219071692: 1, 30.135396987764686: 1, 30.024205908625355: 1, 29.94735733901425: 1, 29.81051578771111: 1, 29.79653178459829: 1, 29.72440865396959: 1, 29.216125776077295: 1, 28.90574090787584: 1, 28.849134396349626: 1, 28.821013763464897: 1, 28.676213904176574: 1, 28.56364713661551: 1, 28.56170736716228: 1, 28.251707801289985: 1, 27.957011512733988: 1, 27.924174340615476: 1, 27.604969801680568: 1, 27.508855398882535: 1, 27.31536066141901: 1, 27.30558924969454: 1, 27.246934532613185: 1, 27.114325836676084: 1, 27.064141301584595: 1, 27.06035417038098: 1, 26.872669050183003: 1, 26.558096937961913: 1, 26.33686292480846: 1, 26.267475245414047: 1, 26.146429718591907: 1, 26.019078859508618: 1, 25.945862326017043: 1, 25.83123731266556: 1, 25.730687658244072: 1, 25.707970555233327: 1, 25.542149735441054: 1, 25.54165774637199: 1, 25.449333808962013: 1, 25.40762990160081: 1, 25.38024584526202: 1, 25.355638360987417: 1, 25.327570353076432: 1, 25.208700394915393: 1, 25.013052833793566: 1, 25.008551213800523: 1, 24.979980811073276: 1, 24.823695134767597: 1, 24.640830429312782: 1, 24.568636405697486: 1, 24.503602641667396: 1, 24.429910404525007: 1, 24.333958590590992: 1, 24.303231383065192: 1, 24.263999560596215: 1, 24.209388208884768: 1, 24.08716721662634: 1, 24.084320249563962: 1, 24.01944696200742: 1, 23.876523850158456: 1, 23.85586248085734: 1, 23.836732824445647: 1, 23.805707754087745: 1, 23.66681939492374: 1, 23.587 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.2751279917485285
# For values of alpha =  0.0001 The log loss is: 1.2919519210764325
# For values of alpha =  0.001 The log loss is: 1.5582236374559784
# For values of alpha =  0.01 The log loss is: 1.9499227509468902
# For values of alpha =  0.1 The log loss is: 2.0389017050568974
# For values of alpha =  1 The log loss is: 2.022285699955656
# For values of best alpha =  1e-05 The train log loss is: 0.7490653457636646
# For values of best alpha =  1e-05 The cross validation log loss is: 1.2751279917485285
# For values of best alpha =  1e-05 The test log loss is: 1.1245489742247425

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 3.355 % of word of test data appeared in train data
# 3.824 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = TfidfVectorizer(max_features=1000)
    var_count_vec = TfidfVectorizer(max_features=1000)
    text_count_vec = TfidfVectorizer(min_df=3,max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 2231)
# (number of data points * number of features) in test data =  (665, 2231)
# (number of data points * number of features) in cross validation data = (532, 2231)

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 27)
# (number of data points * number of features) in test data =  (665, 27)
# (number of data points * number of features) in cross validation data = (532, 27)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------

warnings.filterwarnings("ignore")
alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.230776982449184
# for alpha = 0.0001
# Log Loss : 1.2295457496198494
# for alpha = 0.001
# Log Loss : 1.228325167160416
# for alpha = 0.1
# Log Loss : 1.2204251807492874
# for alpha = 1
# Log Loss : 1.2624269680743998
# for alpha = 10
# Log Loss : 1.4466326591323964
# for alpha = 100
# Log Loss : 1.4690374112997728
# for alpha = 1000
# Log Loss : 1.46876701778924
# For values of best alpha =  0.1 The train log loss is: 0.8063444830960695
# For values of best alpha =  0.1 The cross validation log loss is: 1.2204251807492874
# For values of best alpha =  0.1 The test log loss is: 1.1151134866734553

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.2204251807492874
# Number of missclassified point : 0.40789473684210525
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 2
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0546 0.2335 0.0186 0.0521 0.0412 0.0397 0.551  0.0057 0.0037]]
# Actual Class : 7
# --------------------------------------------------
# 16 Text feature [activation] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 18 Text feature [kinase] present in test data point [True]
# 21 Text feature [downstream] present in test data point [True]
# 22 Text feature [cells] present in test data point [True]
# 23 Text feature [expressing] present in test data point [True]
# 24 Text feature [signaling] present in test data point [True]
# 25 Text feature [independent] present in test data point [True]
# 26 Text feature [presence] present in test data point [True]
# 27 Text feature [factor] present in test data point [True]
# 28 Text feature [contrast] present in test data point [True]
# 29 Text feature [growth] present in test data point [True]
# 31 Text feature [also] present in test data point [True]
# 33 Text feature [constitutive] present in test data point [True]
# 34 Text feature [however] present in test data point [True]
# 35 Text feature [10] present in test data point [True]
# 37 Text feature [oncogenic] present in test data point [True]
# 38 Text feature [activating] present in test data point [True]
# 39 Text feature [well] present in test data point [True]
# 40 Text feature [compared] present in test data point [True]
# 41 Text feature [treatment] present in test data point [True]
# 42 Text feature [previously] present in test data point [True]
# 43 Text feature [shown] present in test data point [True]
# 44 Text feature [inhibitors] present in test data point [True]
# 45 Text feature [mutations] present in test data point [True]
# 46 Text feature [addition] present in test data point [True]
# 47 Text feature [similar] present in test data point [True]
# 48 Text feature [constitutively] present in test data point [True]
# 49 Text feature [showed] present in test data point [True]
# 50 Text feature [may] present in test data point [True]
# 51 Text feature [activate] present in test data point [True]
# 52 Text feature [higher] present in test data point [True]
# 53 Text feature [cell] present in test data point [True]
# 54 Text feature [phosphorylation] present in test data point [True]
# 55 Text feature [treated] present in test data point [True]
# 56 Text feature [recently] present in test data point [True]
# 57 Text feature [suggest] present in test data point [True]
# 58 Text feature [absence] present in test data point [True]
# 59 Text feature [proliferation] present in test data point [True]
# 60 Text feature [found] present in test data point [True]
# 61 Text feature [described] present in test data point [True]
# 62 Text feature [increased] present in test data point [True]
# 63 Text feature [potential] present in test data point [True]
# 64 Text feature [3b] present in test data point [True]
# 68 Text feature [receptor] present in test data point [True]
# 69 Text feature [although] present in test data point [True]
# 70 Text feature [inhibition] present in test data point [True]
# 71 Text feature [without] present in test data point [True]
# 72 Text feature [interestingly] present in test data point [True]
# 73 Text feature [tyrosine] present in test data point [True]
# 74 Text feature [total] present in test data point [True]
# 75 Text feature [fig] present in test data point [True]
# 76 Text feature [observed] present in test data point [True]
# 78 Text feature [survival] present in test data point [True]
# 79 Text feature [mutation] present in test data point [True]
# 80 Text feature [results] present in test data point [True]
# 81 Text feature [using] present in test data point [True]
# 84 Text feature [either] present in test data point [True]
# 85 Text feature [15] present in test data point [True]
# 86 Text feature [12] present in test data point [True]
# 87 Text feature [induced] present in test data point [True]
# 88 Text feature [pathway] present in test data point [True]
# 90 Text feature [reported] present in test data point [True]
# 91 Text feature [identified] present in test data point [True]
# 92 Text feature [consistent] present in test data point [True]
# 93 Text feature [mechanism] present in test data point [True]
# 94 Text feature [two] present in test data point [True]
# 95 Text feature [different] present in test data point [True]
# 96 Text feature [domain] present in test data point [True]
# 97 Text feature [including] present in test data point [True]
# 98 Text feature [effective] present in test data point [True]
# 99 Text feature [therapeutic] present in test data point [True]
# Out of the top  100  features  72 are present in query point

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0496 0.0444 0.017  0.0475 0.037  0.036  0.76   0.0051 0.0033]]
# Actual Class : 5
# --------------------------------------------------
# 16 Text feature [activation] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 18 Text feature [kinase] present in test data point [True]
# 21 Text feature [downstream] present in test data point [True]
# 22 Text feature [cells] present in test data point [True]
# 24 Text feature [signaling] present in test data point [True]
# 25 Text feature [independent] present in test data point [True]
# 26 Text feature [presence] present in test data point [True]
# 27 Text feature [factor] present in test data point [True]
# 28 Text feature [contrast] present in test data point [True]
# 29 Text feature [growth] present in test data point [True]
# 30 Text feature [inhibitor] present in test data point [True]
# 31 Text feature [also] present in test data point [True]
# 32 Text feature [sensitive] present in test data point [True]
# 33 Text feature [constitutive] present in test data point [True]
# 34 Text feature [however] present in test data point [True]
# 35 Text feature [10] present in test data point [True]
# 37 Text feature [oncogenic] present in test data point [True]
# 38 Text feature [activating] present in test data point [True]
# 39 Text feature [well] present in test data point [True]
# 40 Text feature [compared] present in test data point [True]
# 41 Text feature [treatment] present in test data point [True]
# 42 Text feature [previously] present in test data point [True]
# 43 Text feature [shown] present in test data point [True]
# 44 Text feature [inhibitors] present in test data point [True]
# 45 Text feature [mutations] present in test data point [True]
# 46 Text feature [addition] present in test data point [True]
# 47 Text feature [similar] present in test data point [True]
# 48 Text feature [constitutively] present in test data point [True]
# 49 Text feature [showed] present in test data point [True]
# 50 Text feature [may] present in test data point [True]
# 51 Text feature [activate] present in test data point [True]
# 52 Text feature [higher] present in test data point [True]
# 53 Text feature [cell] present in test data point [True]
# 54 Text feature [phosphorylation] present in test data point [True]
# 55 Text feature [treated] present in test data point [True]
# 56 Text feature [recently] present in test data point [True]
# 57 Text feature [suggest] present in test data point [True]
# 58 Text feature [absence] present in test data point [True]
# 59 Text feature [proliferation] present in test data point [True]
# 60 Text feature [found] present in test data point [True]
# 61 Text feature [described] present in test data point [True]
# 62 Text feature [increased] present in test data point [True]
# 63 Text feature [potential] present in test data point [True]
# 64 Text feature [3b] present in test data point [True]
# 68 Text feature [receptor] present in test data point [True]
# 69 Text feature [although] present in test data point [True]
# 70 Text feature [inhibition] present in test data point [True]
# 71 Text feature [without] present in test data point [True]
# 73 Text feature [tyrosine] present in test data point [True]
# 74 Text feature [total] present in test data point [True]
# 76 Text feature [observed] present in test data point [True]
# 77 Text feature [increase] present in test data point [True]
# 78 Text feature [survival] present in test data point [True]
# 79 Text feature [mutation] present in test data point [True]
# 80 Text feature [results] present in test data point [True]
# 81 Text feature [using] present in test data point [True]
# 82 Text feature [pathways] present in test data point [True]
# 83 Text feature [enhanced] present in test data point [True]
# 84 Text feature [either] present in test data point [True]
# 85 Text feature [15] present in test data point [True]
# 86 Text feature [12] present in test data point [True]
# 87 Text feature [induced] present in test data point [True]
# 88 Text feature [pathway] present in test data point [True]
# 89 Text feature [mutant] present in test data point [True]
# 90 Text feature [reported] present in test data point [True]
# 91 Text feature [identified] present in test data point [True]
# 92 Text feature [consistent] present in test data point [True]
# 93 Text feature [mechanism] present in test data point [True]
# 94 Text feature [two] present in test data point [True]
# 95 Text feature [different] present in test data point [True]
# 96 Text feature [domain] present in test data point [True]
# 98 Text feature [effective] present in test data point [True]
# 99 Text feature [therapeutic] present in test data point [True]
# Out of the top  100  features  74 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------
warnings.filterwarnings("ignore")

alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.1916568613402319
# for alpha = 11
# Log Loss : 1.2134485183235437
# for alpha = 15
# Log Loss : 1.2257629140791932
# for alpha = 21
# Log Loss : 1.2338323261114863
# for alpha = 31
# Log Loss : 1.2353073454142376
# for alpha = 41
# Log Loss : 1.2520110235209743
# for alpha = 51
# Log Loss : 1.2803712127884455
# for alpha = 99
# Log Loss : 1.323954465677961
# For values of best alpha =  5 The train log loss is: 0.9295695366357718
# For values of best alpha =  5 The cross validation log loss is: 1.1916568613402319
# For values of best alpha =  5 The test log loss is: 1.1544549958604449

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.1916568613402319
# Number of mis-classified points : 0.4116541353383459
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_onehotCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_onehotCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 5
# Actual Class : 1
# The  5  nearest neighbours of the test points belongs to classes [5 5 6 5 5]
# Fequency of nearest points : Counter({5: 4, 6: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_onehotCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 5
# the k value for knn is 5 and the nearest neighbours of the test points belongs to classes [7 7 7 7 7]
# Fequency of nearest points : Counter({7: 5})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------
warnings.filterwarnings("ignore")

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.204257124814025
# for alpha = 1e-05
# Log Loss : 1.1570864041811415
# for alpha = 0.0001
# Log Loss : 1.068038170400429
# for alpha = 0.001
# Log Loss : 1.0573542281750963
# for alpha = 0.01
# Log Loss : 1.2287511275276486
# for alpha = 0.1
# Log Loss : 1.6187170134879978
# for alpha = 1
# Log Loss : 1.7384077624242922
# for alpha = 10
# Log Loss : 1.7529849954987327
# for alpha = 100
# Log Loss : 1.75461429761575
# For values of best alpha =  0.001 The train log loss is: 0.8087958333338201
# For values of best alpha =  0.001 The cross validation log loss is: 1.0573542281750963
# For values of best alpha =  0.001 The test log loss is: 0.9853175959704773

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.0573542281750963
# Number of mis-classified points : 0.37781954887218044
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 2
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[9.700e-03 2.820e-01 2.000e-03 9.000e-03 2.120e-02 7.700e-03 6.665e-01
#   1.600e-03 2.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# 13 Text feature [activated] present in test data point [True]
# 16 Text feature [constitutive] present in test data point [True]
# 20 Text feature [activation] present in test data point [True]
# 22 Text feature [ligand] present in test data point [True]
# 23 Text feature [oncogenic] present in test data point [True]
# 24 Text feature [oncogene] present in test data point [True]
# 27 Text feature [transforming] present in test data point [True]
# 28 Text feature [activating] present in test data point [True]
# 30 Text feature [downstream] present in test data point [True]
# 38 Text feature [transformed] present in test data point [True]
# 41 Text feature [3t3] present in test data point [True]
# 42 Text feature [activate] present in test data point [True]
# 48 Text feature [signaling] present in test data point [True]
# 49 Text feature [constitutively] present in test data point [True]
# 51 Text feature [factor] present in test data point [True]
# 53 Text feature [expressing] present in test data point [True]
# 56 Text feature [mapk] present in test data point [True]
# 62 Text feature [transformation] present in test data point [True]
# 65 Text feature [stimulation] present in test data point [True]
# 66 Text feature [codon] present in test data point [True]
# 74 Text feature [gtp] present in test data point [True]
# 76 Text feature [phosphorylation] present in test data point [True]
# 79 Text feature [tyrosine] present in test data point [True]
# 82 Text feature [overexpression] present in test data point [True]
# 85 Text feature [malignant] present in test data point [True]
# 89 Text feature [amplification] present in test data point [True]
# 90 Text feature [leukemia] present in test data point [True]
# 91 Text feature [ras] present in test data point [True]
# 92 Text feature [growth] present in test data point [True]
# 93 Text feature [proliferation] present in test data point [True]
# 101 Text feature [presence] present in test data point [True]
# 102 Text feature [3b] present in test data point [True]
# 111 Text feature [absence] present in test data point [True]
# 113 Text feature [stably] present in test data point [True]
# 114 Text feature [open] present in test data point [True]
# 119 Text feature [basal] present in test data point [True]
# 120 Text feature [raf] present in test data point [True]
# 123 Text feature [pathway] present in test data point [True]
# 124 Text feature [factors] present in test data point [True]
# 126 Text feature [kinase] present in test data point [True]
# 129 Text feature [differentiation] present in test data point [True]
# 132 Text feature [2b] present in test data point [True]
# 133 Text feature [transduced] present in test data point [True]
# 134 Text feature [elevated] present in test data point [True]
# 135 Text feature [epithelial] present in test data point [True]
# 140 Text feature [cells] present in test data point [True]
# 143 Text feature [wt] present in test data point [True]
# 149 Text feature [2a] present in test data point [True]
# 155 Text feature [lung] present in test data point [True]
# 162 Text feature [membrane] present in test data point [True]
# 164 Text feature [contrast] present in test data point [True]
# 166 Text feature [induced] present in test data point [True]
# 168 Text feature [potent] present in test data point [True]
# 169 Text feature [receptor] present in test data point [True]
# 176 Text feature [lesions] present in test data point [True]
# 186 Text feature [cdna] present in test data point [True]
# 193 Text feature [phosphorylated] present in test data point [True]
# 194 Text feature [probe] present in test data point [True]
# 196 Text feature [specimens] present in test data point [True]
# 202 Text feature [derived] present in test data point [True]
# 204 Text feature [erk] present in test data point [True]
# 211 Text feature [gain] present in test data point [True]
# 225 Text feature [survival] present in test data point [True]
# 234 Text feature [signals] present in test data point [True]
# 238 Text feature [days] present in test data point [True]
# 242 Text feature [insertion] present in test data point [True]
# 243 Text feature [positive] present in test data point [True]
# 251 Text feature [effective] present in test data point [True]
# 259 Text feature [bp] present in test data point [True]
# 276 Text feature [conditions] present in test data point [True]
# 281 Text feature [inhibition] present in test data point [True]
# 283 Text feature [fusion] present in test data point [True]
# 306 Text feature [blood] present in test data point [True]
# 312 Text feature [signalling] present in test data point [True]
# 318 Text feature [leading] present in test data point [True]
# 335 Text feature [demonstrated] present in test data point [True]
# 340 Text feature [independent] present in test data point [True]
# 354 Text feature [kit] present in test data point [True]
# 375 Text feature [occur] present in test data point [True]
# 401 Text feature [mutants] present in test data point [True]
# 406 Text feature [long] present in test data point [True]
# 415 Text feature [lead] present in test data point [True]
# 425 Text feature [carcinomas] present in test data point [True]
# 428 Text feature [kras] present in test data point [True]
# 429 Text feature [size] present in test data point [True]
# 438 Text feature [tumors] present in test data point [True]
# 440 Text feature [61] present in test data point [True]
# 444 Text feature [genomic] present in test data point [True]
# 456 Text feature [interestingly] present in test data point [True]
# 457 Text feature [induce] present in test data point [True]
# 460 Text feature [medium] present in test data point [True]
# 462 Text feature [years] present in test data point [True]
# 465 Text feature [blot] present in test data point [True]
# 469 Text feature [without] present in test data point [True]
# 470 Text feature [braf] present in test data point [True]
# 485 Text feature [fold] present in test data point [True]
# 489 Text feature [fig] present in test data point [True]
# 493 Text feature [approximately] present in test data point [True]
# 495 Text feature [signal] present in test data point [True]
# 496 Text feature [inhibitors] present in test data point [True]
# 497 Text feature [mechanisms] present in test data point [True]
# 499 Text feature [treated] present in test data point [True]
# Out of the top  500  features  102 are present in query point

# %% [markdown]
# <h5>4.3.1.3.2. Incorrectly Classified point</h5>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[1.330e-02 2.380e-02 4.280e-02 1.430e-02 2.540e-02 6.400e-03 8.706e-01
#   2.700e-03 8.000e-04]]
# Actual Class : 5
# --------------------------------------------------
# 13 Text feature [activated] present in test data point [True]
# 16 Text feature [constitutive] present in test data point [True]
# 20 Text feature [activation] present in test data point [True]
# 22 Text feature [ligand] present in test data point [True]
# 23 Text feature [oncogenic] present in test data point [True]
# 28 Text feature [activating] present in test data point [True]
# 30 Text feature [downstream] present in test data point [True]
# 34 Text feature [receptors] present in test data point [True]
# 42 Text feature [activate] present in test data point [True]
# 47 Text feature [enhanced] present in test data point [True]
# 48 Text feature [signaling] present in test data point [True]
# 49 Text feature [constitutively] present in test data point [True]
# 51 Text feature [factor] present in test data point [True]
# 54 Text feature [ba] present in test data point [True]
# 55 Text feature [pathways] present in test data point [True]
# 57 Text feature [f3] present in test data point [True]
# 62 Text feature [transformation] present in test data point [True]
# 63 Text feature [serum] present in test data point [True]
# 65 Text feature [stimulation] present in test data point [True]
# 66 Text feature [codon] present in test data point [True]
# 73 Text feature [akt] present in test data point [True]
# 76 Text feature [phosphorylation] present in test data point [True]
# 79 Text feature [tyrosine] present in test data point [True]
# 80 Text feature [inhibited] present in test data point [True]
# 82 Text feature [overexpression] present in test data point [True]
# 85 Text feature [malignant] present in test data point [True]
# 86 Text feature [phospho] present in test data point [True]
# 89 Text feature [amplification] present in test data point [True]
# 90 Text feature [leukemia] present in test data point [True]
# 92 Text feature [growth] present in test data point [True]
# 93 Text feature [proliferation] present in test data point [True]
# 96 Text feature [sensitive] present in test data point [True]
# 99 Text feature [il] present in test data point [True]
# 101 Text feature [presence] present in test data point [True]
# 102 Text feature [3b] present in test data point [True]
# 105 Text feature [stat3] present in test data point [True]
# 109 Text feature [cultured] present in test data point [True]
# 110 Text feature [inhibitor] present in test data point [True]
# 111 Text feature [absence] present in test data point [True]
# 113 Text feature [stably] present in test data point [True]
# 117 Text feature [extracellular] present in test data point [True]
# 118 Text feature [concentrations] present in test data point [True]
# 121 Text feature [pdgfr] present in test data point [True]
# 123 Text feature [pathway] present in test data point [True]
# 126 Text feature [kinase] present in test data point [True]
# 127 Text feature [regulated] present in test data point [True]
# 129 Text feature [differentiation] present in test data point [True]
# 130 Text feature [egfr] present in test data point [True]
# 132 Text feature [2b] present in test data point [True]
# 134 Text feature [elevated] present in test data point [True]
# 140 Text feature [cells] present in test data point [True]
# 147 Text feature [increase] present in test data point [True]
# 149 Text feature [2a] present in test data point [True]
# 162 Text feature [membrane] present in test data point [True]
# 164 Text feature [contrast] present in test data point [True]
# 166 Text feature [induced] present in test data point [True]
# 168 Text feature [potent] present in test data point [True]
# 169 Text feature [receptor] present in test data point [True]
# 186 Text feature [cdna] present in test data point [True]
# 193 Text feature [phosphorylated] present in test data point [True]
# 194 Text feature [probe] present in test data point [True]
# 196 Text feature [specimens] present in test data point [True]
# 202 Text feature [derived] present in test data point [True]
# 211 Text feature [gain] present in test data point [True]
# 213 Text feature [gists] present in test data point [True]
# 225 Text feature [survival] present in test data point [True]
# 238 Text feature [days] present in test data point [True]
# 242 Text feature [insertion] present in test data point [True]
# 243 Text feature [positive] present in test data point [True]
# 249 Text feature [adenocarcinoma] present in test data point [True]
# 251 Text feature [effective] present in test data point [True]
# 276 Text feature [conditions] present in test data point [True]
# 281 Text feature [inhibition] present in test data point [True]
# 283 Text feature [fusion] present in test data point [True]
# 305 Text feature [express] present in test data point [True]
# 335 Text feature [demonstrated] present in test data point [True]
# 340 Text feature [independent] present in test data point [True]
# 354 Text feature [kit] present in test data point [True]
# 363 Text feature [met] present in test data point [True]
# 377 Text feature [numbers] present in test data point [True]
# 385 Text feature [pdgfra] present in test data point [True]
# 390 Text feature [hours] present in test data point [True]
# 425 Text feature [carcinomas] present in test data point [True]
# 429 Text feature [size] present in test data point [True]
# 438 Text feature [tumors] present in test data point [True]
# 444 Text feature [genomic] present in test data point [True]
# 446 Text feature [nsclc] present in test data point [True]
# 449 Text feature [advanced] present in test data point [True]
# 457 Text feature [induce] present in test data point [True]
# 460 Text feature [medium] present in test data point [True]
# 462 Text feature [years] present in test data point [True]
# 469 Text feature [without] present in test data point [True]
# 474 Text feature [versus] present in test data point [True]
# 475 Text feature [myeloid] present in test data point [True]
# 485 Text feature [fold] present in test data point [True]
# 491 Text feature [exhibited] present in test data point [True]
# 493 Text feature [approximately] present in test data point [True]
# 495 Text feature [signal] present in test data point [True]
# 496 Text feature [inhibitors] present in test data point [True]
# 497 Text feature [mechanisms] present in test data point [True]
# 499 Text feature [treated] present in test data point [True]
# Out of the top  500  features  101 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------
warnings.filterwarnings("ignore")
alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2017556259196547
# for alpha = 1e-05
# Log Loss : 1.2068933023717632
# for alpha = 0.0001
# Log Loss : 1.10073275037583
# for alpha = 0.001
# Log Loss : 1.1556060389907066
# for alpha = 0.01
# Log Loss : 1.3468695545626455
# for alpha = 0.1
# Log Loss : 1.6132528642914552
# for alpha = 1
# Log Loss : 1.7226602767859647
# For values of best alpha =  0.0001 The train log loss is: 0.5710003472540759
# For values of best alpha =  0.0001 The cross validation log loss is: 1.10073275037583
# For values of best alpha =  0.0001 The test log loss is: 1.0031231665765308

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 1.10073275037583
# Number of mis-classified points : 0.3609022556390977
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 2
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[9.300e-03 2.923e-01 8.000e-04 1.250e-02 9.000e-03 4.100e-03 6.713e-01
#   6.000e-04 0.000e+00]]
# Actual Class : 7
# --------------------------------------------------
# 2 Text feature [codon] present in test data point [True]
# 9 Text feature [ligand] present in test data point [True]
# 13 Text feature [activated] present in test data point [True]
# 14 Text feature [transformed] present in test data point [True]
# 19 Text feature [downstream] present in test data point [True]
# 27 Text feature [overexpression] present in test data point [True]
# 29 Text feature [derived] present in test data point [True]
# 30 Text feature [oncogene] present in test data point [True]
# 31 Text feature [open] present in test data point [True]
# 42 Text feature [activating] present in test data point [True]
# 44 Text feature [3b] present in test data point [True]
# 49 Text feature [presence] present in test data point [True]
# 51 Text feature [mapk] present in test data point [True]
# 54 Text feature [bp] present in test data point [True]
# 64 Text feature [2b] present in test data point [True]
# 65 Text feature [activation] present in test data point [True]
# 70 Text feature [factors] present in test data point [True]
# 80 Text feature [approximately] present in test data point [True]
# 82 Text feature [activate] present in test data point [True]
# 83 Text feature [leukemia] present in test data point [True]
# 86 Text feature [transforming] present in test data point [True]
# 94 Text feature [elevated] present in test data point [True]
# 104 Text feature [constitutive] present in test data point [True]
# 111 Text feature [amplification] present in test data point [True]
# 112 Text feature [oncogenic] present in test data point [True]
# 114 Text feature [factor] present in test data point [True]
# 119 Text feature [phosphorylated] present in test data point [True]
# 126 Text feature [signals] present in test data point [True]
# 127 Text feature [gtp] present in test data point [True]
# 130 Text feature [stably] present in test data point [True]
# 138 Text feature [lead] present in test data point [True]
# 147 Text feature [signaling] present in test data point [True]
# 148 Text feature [level] present in test data point [True]
# 152 Text feature [insertion] present in test data point [True]
# 159 Text feature [2a] present in test data point [True]
# 163 Text feature [conditions] present in test data point [True]
# 173 Text feature [malignant] present in test data point [True]
# 177 Text feature [size] present in test data point [True]
# 178 Text feature [contrast] present in test data point [True]
# 179 Text feature [wt] present in test data point [True]
# 180 Text feature [raf] present in test data point [True]
# 182 Text feature [mechanisms] present in test data point [True]
# 183 Text feature [phosphorylation] present in test data point [True]
# 184 Text feature [high] present in test data point [True]
# 189 Text feature [provided] present in test data point [True]
# 190 Text feature [leading] present in test data point [True]
# 191 Text feature [expressing] present in test data point [True]
# 193 Text feature [stimulation] present in test data point [True]
# 199 Text feature [basal] present in test data point [True]
# 203 Text feature [24] present in test data point [True]
# 204 Text feature [fold] present in test data point [True]
# 207 Text feature [ras] present in test data point [True]
# 208 Text feature [distinct] present in test data point [True]
# 209 Text feature [harboring] present in test data point [True]
# 211 Text feature [lesions] present in test data point [True]
# 214 Text feature [position] present in test data point [True]
# 215 Text feature [demonstrated] present in test data point [True]
# 220 Text feature [differentiation] present in test data point [True]
# 221 Text feature [use] present in test data point [True]
# 227 Text feature [44] present in test data point [True]
# 229 Text feature [occur] present in test data point [True]
# 231 Text feature [positive] present in test data point [True]
# 241 Text feature [tyrosine] present in test data point [True]
# 243 Text feature [prior] present in test data point [True]
# 247 Text feature [tissues] present in test data point [True]
# 248 Text feature [long] present in test data point [True]
# 249 Text feature [materials] present in test data point [True]
# 251 Text feature [regions] present in test data point [True]
# 255 Text feature [51] present in test data point [True]
# 258 Text feature [fig] present in test data point [True]
# 260 Text feature [years] present in test data point [True]
# 264 Text feature [proliferation] present in test data point [True]
# 267 Text feature [3t3] present in test data point [True]
# 269 Text feature [epithelial] present in test data point [True]
# 273 Text feature [signalling] present in test data point [True]
# 274 Text feature [membrane] present in test data point [True]
# 275 Text feature [either] present in test data point [True]
# 277 Text feature [37] present in test data point [True]
# 278 Text feature [suggest] present in test data point [True]
# 283 Text feature [sites] present in test data point [True]
# 297 Text feature [gain] present in test data point [True]
# 298 Text feature [61] present in test data point [True]
# 304 Text feature [disease] present in test data point [True]
# 307 Text feature [examined] present in test data point [True]
# 308 Text feature [effective] present in test data point [True]
# 322 Text feature [coding] present in test data point [True]
# 323 Text feature [interestingly] present in test data point [True]
# 326 Text feature [series] present in test data point [True]
# 328 Text feature [blood] present in test data point [True]
# 334 Text feature [growth] present in test data point [True]
# 338 Text feature [cdna] present in test data point [True]
# 341 Text feature [developed] present in test data point [True]
# 343 Text feature [absence] present in test data point [True]
# 347 Text feature [recently] present in test data point [True]
# 348 Text feature [70] present in test data point [True]
# 350 Text feature [genomic] present in test data point [True]
# 355 Text feature [formed] present in test data point [True]
# 356 Text feature [induced] present in test data point [True]
# 359 Text feature [lung] present in test data point [True]
# 361 Text feature [potent] present in test data point [True]
# 362 Text feature [mutants] present in test data point [True]
# 363 Text feature [previously] present in test data point [True]
# 367 Text feature [50] present in test data point [True]
# 369 Text feature [cells] present in test data point [True]
# 372 Text feature [additional] present in test data point [True]
# 375 Text feature [gfp] present in test data point [True]
# 376 Text feature [transcription] present in test data point [True]
# 377 Text feature [primer] present in test data point [True]
# 379 Text feature [six] present in test data point [True]
# 385 Text feature [form] present in test data point [True]
# 392 Text feature [tumors] present in test data point [True]
# 394 Text feature [increased] present in test data point [True]
# 396 Text feature [total] present in test data point [True]
# 403 Text feature [probe] present in test data point [True]
# 409 Text feature [directly] present in test data point [True]
# 410 Text feature [free] present in test data point [True]
# 411 Text feature [vector] present in test data point [True]
# 416 Text feature [stem] present in test data point [True]
# 420 Text feature [kit] present in test data point [True]
# 421 Text feature [mediated] present in test data point [True]
# 428 Text feature [transfection] present in test data point [True]
# 430 Text feature [calculated] present in test data point [True]
# 434 Text feature [cancers] present in test data point [True]
# 435 Text feature [pathway] present in test data point [True]
# 437 Text feature [nucleotide] present in test data point [True]
# 438 Text feature [specimens] present in test data point [True]
# 440 Text feature [progression] present in test data point [True]
# 441 Text feature [negative] present in test data point [True]
# 444 Text feature [loop] present in test data point [True]
# 448 Text feature [transduced] present in test data point [True]
# 450 Text feature [substitution] present in test data point [True]
# 453 Text feature [led] present in test data point [True]
# 454 Text feature [mechanism] present in test data point [True]
# 455 Text feature [showed] present in test data point [True]
# 456 Text feature [75] present in test data point [True]
# 458 Text feature [carcinomas] present in test data point [True]
# 459 Text feature [transformation] present in test data point [True]
# 460 Text feature [common] present in test data point [True]
# 461 Text feature [available] present in test data point [True]
# 464 Text feature [hr] present in test data point [True]
# 465 Text feature [four] present in test data point [True]
# 466 Text feature [indicating] present in test data point [True]
# 470 Text feature [43] present in test data point [True]
# 475 Text feature [leads] present in test data point [True]
# 476 Text feature [added] present in test data point [True]
# 477 Text feature [region] present in test data point [True]
# 478 Text feature [12] present in test data point [True]
# 479 Text feature [events] present in test data point [True]
# 481 Text feature [survival] present in test data point [True]
# 492 Text feature [product] present in test data point [True]
# 495 Text feature [ratio] present in test data point [True]
# 496 Text feature [forms] present in test data point [True]
# 497 Text feature [dependent] present in test data point [True]
# 498 Text feature [kinase] present in test data point [True]
# Out of the top  500  features  154 are present in query point

# %% [markdown]
# <h4>4.3.2.4. Feature Importance, Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[1.07e-02 1.94e-02 2.39e-02 1.19e-02 3.59e-02 3.90e-03 8.92e-01 1.80e-03
#   5.00e-04]]
# Actual Class : 5
# --------------------------------------------------
# 2 Text feature [codon] present in test data point [True]
# 9 Text feature [ligand] present in test data point [True]
# 13 Text feature [activated] present in test data point [True]
# 19 Text feature [downstream] present in test data point [True]
# 27 Text feature [overexpression] present in test data point [True]
# 29 Text feature [derived] present in test data point [True]
# 32 Text feature [receptors] present in test data point [True]
# 34 Text feature [enhanced] present in test data point [True]
# 42 Text feature [activating] present in test data point [True]
# 44 Text feature [3b] present in test data point [True]
# 47 Text feature [regulated] present in test data point [True]
# 49 Text feature [presence] present in test data point [True]
# 64 Text feature [2b] present in test data point [True]
# 65 Text feature [activation] present in test data point [True]
# 71 Text feature [sensitive] present in test data point [True]
# 80 Text feature [approximately] present in test data point [True]
# 82 Text feature [activate] present in test data point [True]
# 83 Text feature [leukemia] present in test data point [True]
# 88 Text feature [increase] present in test data point [True]
# 89 Text feature [concentrations] present in test data point [True]
# 94 Text feature [elevated] present in test data point [True]
# 95 Text feature [inhibited] present in test data point [True]
# 104 Text feature [constitutive] present in test data point [True]
# 107 Text feature [pathways] present in test data point [True]
# 111 Text feature [amplification] present in test data point [True]
# 112 Text feature [oncogenic] present in test data point [True]
# 114 Text feature [factor] present in test data point [True]
# 115 Text feature [cultured] present in test data point [True]
# 119 Text feature [phosphorylated] present in test data point [True]
# 130 Text feature [stably] present in test data point [True]
# 147 Text feature [signaling] present in test data point [True]
# 148 Text feature [level] present in test data point [True]
# 152 Text feature [insertion] present in test data point [True]
# 159 Text feature [2a] present in test data point [True]
# 161 Text feature [inhibitor] present in test data point [True]
# 163 Text feature [conditions] present in test data point [True]
# 168 Text feature [akt] present in test data point [True]
# 173 Text feature [malignant] present in test data point [True]
# 177 Text feature [size] present in test data point [True]
# 178 Text feature [contrast] present in test data point [True]
# 182 Text feature [mechanisms] present in test data point [True]
# 183 Text feature [phosphorylation] present in test data point [True]
# 184 Text feature [high] present in test data point [True]
# 193 Text feature [stimulation] present in test data point [True]
# 203 Text feature [24] present in test data point [True]
# 204 Text feature [fold] present in test data point [True]
# 215 Text feature [demonstrated] present in test data point [True]
# 220 Text feature [differentiation] present in test data point [True]
# 221 Text feature [use] present in test data point [True]
# 231 Text feature [positive] present in test data point [True]
# 235 Text feature [caused] present in test data point [True]
# 241 Text feature [tyrosine] present in test data point [True]
# 243 Text feature [prior] present in test data point [True]
# 247 Text feature [tissues] present in test data point [True]
# 249 Text feature [materials] present in test data point [True]
# 250 Text feature [egfr] present in test data point [True]
# 251 Text feature [regions] present in test data point [True]
# 260 Text feature [years] present in test data point [True]
# 264 Text feature [proliferation] present in test data point [True]
# 274 Text feature [membrane] present in test data point [True]
# 275 Text feature [either] present in test data point [True]
# 277 Text feature [37] present in test data point [True]
# 278 Text feature [suggest] present in test data point [True]
# 280 Text feature [gists] present in test data point [True]
# 283 Text feature [sites] present in test data point [True]
# 287 Text feature [ba] present in test data point [True]
# 288 Text feature [fact] present in test data point [True]
# 289 Text feature [f3] present in test data point [True]
# 295 Text feature [adenocarcinoma] present in test data point [True]
# 297 Text feature [gain] present in test data point [True]
# 304 Text feature [disease] present in test data point [True]
# 307 Text feature [examined] present in test data point [True]
# 308 Text feature [effective] present in test data point [True]
# 309 Text feature [versus] present in test data point [True]
# 312 Text feature [000] present in test data point [True]
# 318 Text feature [responses] present in test data point [True]
# 320 Text feature [pdgfr] present in test data point [True]
# 322 Text feature [coding] present in test data point [True]
# 334 Text feature [growth] present in test data point [True]
# 337 Text feature [phospho] present in test data point [True]
# 338 Text feature [cdna] present in test data point [True]
# 341 Text feature [developed] present in test data point [True]
# 343 Text feature [absence] present in test data point [True]
# 347 Text feature [recently] present in test data point [True]
# 348 Text feature [70] present in test data point [True]
# 349 Text feature [extracellular] present in test data point [True]
# 350 Text feature [genomic] present in test data point [True]
# 351 Text feature [numbers] present in test data point [True]
# 356 Text feature [induced] present in test data point [True]
# 361 Text feature [potent] present in test data point [True]
# 363 Text feature [previously] present in test data point [True]
# 364 Text feature [advanced] present in test data point [True]
# 365 Text feature [day] present in test data point [True]
# 367 Text feature [50] present in test data point [True]
# 369 Text feature [cells] present in test data point [True]
# 372 Text feature [additional] present in test data point [True]
# 375 Text feature [gfp] present in test data point [True]
# 376 Text feature [transcription] present in test data point [True]
# 377 Text feature [primer] present in test data point [True]
# 385 Text feature [form] present in test data point [True]
# 392 Text feature [tumors] present in test data point [True]
# 394 Text feature [increased] present in test data point [True]
# 396 Text feature [total] present in test data point [True]
# 399 Text feature [initial] present in test data point [True]
# 403 Text feature [probe] present in test data point [True]
# 409 Text feature [directly] present in test data point [True]
# 411 Text feature [vector] present in test data point [True]
# 412 Text feature [chain] present in test data point [True]
# 416 Text feature [stem] present in test data point [True]
# 420 Text feature [kit] present in test data point [True]
# 421 Text feature [mediated] present in test data point [True]
# 424 Text feature [hours] present in test data point [True]
# 428 Text feature [transfection] present in test data point [True]
# 430 Text feature [calculated] present in test data point [True]
# 431 Text feature [stat3] present in test data point [True]
# 433 Text feature [myeloid] present in test data point [True]
# 434 Text feature [cancers] present in test data point [True]
# 435 Text feature [pathway] present in test data point [True]
# 437 Text feature [nucleotide] present in test data point [True]
# 438 Text feature [specimens] present in test data point [True]
# 441 Text feature [negative] present in test data point [True]
# 445 Text feature [exhibited] present in test data point [True]
# 450 Text feature [substitution] present in test data point [True]
# 454 Text feature [mechanism] present in test data point [True]
# 455 Text feature [showed] present in test data point [True]
# 456 Text feature [75] present in test data point [True]
# 458 Text feature [carcinomas] present in test data point [True]
# 459 Text feature [transformation] present in test data point [True]
# 460 Text feature [common] present in test data point [True]
# 461 Text feature [available] present in test data point [True]
# 464 Text feature [hr] present in test data point [True]
# 465 Text feature [four] present in test data point [True]
# 469 Text feature [incubated] present in test data point [True]
# 476 Text feature [added] present in test data point [True]
# 477 Text feature [region] present in test data point [True]
# 478 Text feature [12] present in test data point [True]
# 481 Text feature [survival] present in test data point [True]
# 482 Text feature [state] present in test data point [True]
# 488 Text feature [serum] present in test data point [True]
# 492 Text feature [product] present in test data point [True]
# 494 Text feature [regulation] present in test data point [True]
# 496 Text feature [forms] present in test data point [True]
# 497 Text feature [dependent] present in test data point [True]
# 498 Text feature [kinase] present in test data point [True]
# Out of the top  500  features  144 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.165209163689912
# for C = 0.0001
# Log Loss : 1.1529805874276662
# for C = 0.001
# Log Loss : 1.1440027198240146
# for C = 0.01
# Log Loss : 1.3143584857766688
# for C = 0.1
# Log Loss : 1.6539117524203477
# for C = 1
# Log Loss : 1.7549658459918007
# for C = 10
# Log Loss : 1.7549660037406345
# for C = 100
# Log Loss : 1.754966006285432
# For values of best alpha =  0.001 The train log loss is: 0.7797386843173332
# For values of best alpha =  0.001 The cross validation log loss is: 1.1440027198240146
# For values of best alpha =  0.001 The test log loss is: 1.0518902253266098

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1440027198240146
# Number of mis-classified points : 0.3815789473684211
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 2
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])  
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0581 0.2613 0.0045 0.0695 0.022  0.0144 0.5668 0.0023 0.0011]]
# Actual Class : 7
# --------------------------------------------------
# 10 Text feature [ligand] present in test data point [True]
# 11 Text feature [codon] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 21 Text feature [constitutive] present in test data point [True]
# 24 Text feature [activation] present in test data point [True]
# 32 Text feature [activating] present in test data point [True]
# 33 Text feature [activate] present in test data point [True]
# 34 Text feature [downstream] present in test data point [True]
# 36 Text feature [derived] present in test data point [True]
# 37 Text feature [3b] present in test data point [True]
# 42 Text feature [transformed] present in test data point [True]
# 44 Text feature [2b] present in test data point [True]
# 45 Text feature [wt] present in test data point [True]
# 46 Text feature [factor] present in test data point [True]
# 48 Text feature [transforming] present in test data point [True]
# 49 Text feature [presence] present in test data point [True]
# 50 Text feature [factors] present in test data point [True]
# 51 Text feature [leukemia] present in test data point [True]
# 54 Text feature [oncogenic] present in test data point [True]
# 55 Text feature [oncogene] present in test data point [True]
# 70 Text feature [open] present in test data point [True]
# 72 Text feature [expressing] present in test data point [True]
# 73 Text feature [signaling] present in test data point [True]
# 74 Text feature [3t3] present in test data point [True]
# 76 Text feature [overexpression] present in test data point [True]
# 77 Text feature [phosphorylated] present in test data point [True]
# 79 Text feature [2a] present in test data point [True]
# 82 Text feature [amplification] present in test data point [True]
# 85 Text feature [mapk] present in test data point [True]
# 86 Text feature [signals] present in test data point [True]
# 89 Text feature [raf] present in test data point [True]
# 90 Text feature [lead] present in test data point [True]
# 93 Text feature [gtp] present in test data point [True]
# 94 Text feature [phosphorylation] present in test data point [True]
# 95 Text feature [absence] present in test data point [True]
# 96 Text feature [approximately] present in test data point [True]
# 173 Text feature [insertion] present in test data point [True]
# 175 Text feature [provided] present in test data point [True]
# 176 Text feature [fold] present in test data point [True]
# 178 Text feature [proliferation] present in test data point [True]
# 179 Text feature [bp] present in test data point [True]
# 182 Text feature [effective] present in test data point [True]
# 184 Text feature [years] present in test data point [True]
# 186 Text feature [prior] present in test data point [True]
# 188 Text feature [occur] present in test data point [True]
# 189 Text feature [stably] present in test data point [True]
# 190 Text feature [61] present in test data point [True]
# 191 Text feature [mutants] present in test data point [True]
# 192 Text feature [stimulation] present in test data point [True]
# 193 Text feature [growth] present in test data point [True]
# 194 Text feature [position] present in test data point [True]
# 195 Text feature [differentiation] present in test data point [True]
# 196 Text feature [conditions] present in test data point [True]
# 197 Text feature [high] present in test data point [True]
# 199 Text feature [positive] present in test data point [True]
# 202 Text feature [size] present in test data point [True]
# 203 Text feature [examined] present in test data point [True]
# 263 Text feature [epithelial] present in test data point [True]
# 265 Text feature [24] present in test data point [True]
# 267 Text feature [elevated] present in test data point [True]
# 268 Text feature [cells] present in test data point [True]
# 272 Text feature [ras] present in test data point [True]
# 273 Text feature [malignant] present in test data point [True]
# 276 Text feature [form] present in test data point [True]
# 280 Text feature [mechanism] present in test data point [True]
# 281 Text feature [gain] present in test data point [True]
# 282 Text feature [basal] present in test data point [True]
# 283 Text feature [use] present in test data point [True]
# 284 Text feature [transduced] present in test data point [True]
# 285 Text feature [suggest] present in test data point [True]
# 287 Text feature [contrast] present in test data point [True]
# 288 Text feature [fig] present in test data point [True]
# 289 Text feature [leading] present in test data point [True]
# 295 Text feature [lesions] present in test data point [True]
# 296 Text feature [either] present in test data point [True]
# 297 Text feature [cdna] present in test data point [True]
# 298 Text feature [tyrosine] present in test data point [True]
# 299 Text feature [fusion] present in test data point [True]
# 300 Text feature [essential] present in test data point [True]
# 302 Text feature [added] present in test data point [True]
# 303 Text feature [44] present in test data point [True]
# 304 Text feature [membrane] present in test data point [True]
# 305 Text feature [level] present in test data point [True]
# 308 Text feature [harboring] present in test data point [True]
# 310 Text feature [without] present in test data point [True]
# 312 Text feature [reaction] present in test data point [True]
# 314 Text feature [constitutively] present in test data point [True]
# 315 Text feature [recently] present in test data point [True]
# 318 Text feature [domain] present in test data point [True]
# 321 Text feature [stem] present in test data point [True]
# 322 Text feature [nucleotide] present in test data point [True]
# 324 Text feature [mechanisms] present in test data point [True]
# 325 Text feature [gfp] present in test data point [True]
# 326 Text feature [previously] present in test data point [True]
# 327 Text feature [51] present in test data point [True]
# 329 Text feature [blood] present in test data point [True]
# 332 Text feature [transcription] present in test data point [True]
# 381 Text feature [indicating] present in test data point [True]
# 383 Text feature [total] present in test data point [True]
# 387 Text feature [pathway] present in test data point [True]
# 388 Text feature [induced] present in test data point [True]
# 389 Text feature [demonstrated] present in test data point [True]
# 394 Text feature [sufficient] present in test data point [True]
# 396 Text feature [additional] present in test data point [True]
# 399 Text feature [increased] present in test data point [True]
# 401 Text feature [kit] present in test data point [True]
# 402 Text feature [showed] present in test data point [True]
# 403 Text feature [materials] present in test data point [True]
# 404 Text feature [12] present in test data point [True]
# 405 Text feature [potent] present in test data point [True]
# 406 Text feature [disease] present in test data point [True]
# 407 Text feature [myc] present in test data point [True]
# 409 Text feature [probe] present in test data point [True]
# 411 Text feature [tumors] present in test data point [True]
# 412 Text feature [long] present in test data point [True]
# 413 Text feature [independent] present in test data point [True]
# 414 Text feature [university] present in test data point [True]
# 416 Text feature [carcinomas] present in test data point [True]
# 417 Text feature [regions] present in test data point [True]
# 418 Text feature [hr] present in test data point [True]
# 419 Text feature [made] present in test data point [True]
# 420 Text feature [50] present in test data point [True]
# 423 Text feature [lung] present in test data point [True]
# 426 Text feature [directly] present in test data point [True]
# 427 Text feature [distinct] present in test data point [True]
# 429 Text feature [interestingly] present in test data point [True]
# 434 Text feature [specimens] present in test data point [True]
# 435 Text feature [series] present in test data point [True]
# 436 Text feature [genomic] present in test data point [True]
# 437 Text feature [possibility] present in test data point [True]
# 438 Text feature [signal] present in test data point [True]
# 439 Text feature [dependent] present in test data point [True]
# 444 Text feature [five] present in test data point [True]
# 445 Text feature [sensitivity] present in test data point [True]
# 449 Text feature [75] present in test data point [True]
# 450 Text feature [described] present in test data point [True]
# 451 Text feature [negative] present in test data point [True]
# 453 Text feature [formed] present in test data point [True]
# 455 Text feature [endogenous] present in test data point [True]
# 457 Text feature [report] present in test data point [True]
# 459 Text feature [new] present in test data point [True]
# Out of the top  500  features  141 are present in query point

# %% [markdown]
# <h4>4.3.3.2. For Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0513 0.0243 0.0161 0.0411 0.0387 0.0158 0.8071 0.0033 0.0024]]
# Actual Class : 5
# --------------------------------------------------
# 10 Text feature [ligand] present in test data point [True]
# 11 Text feature [codon] present in test data point [True]
# 17 Text feature [activated] present in test data point [True]
# 21 Text feature [constitutive] present in test data point [True]
# 24 Text feature [activation] present in test data point [True]
# 32 Text feature [activating] present in test data point [True]
# 33 Text feature [activate] present in test data point [True]
# 34 Text feature [downstream] present in test data point [True]
# 35 Text feature [sensitive] present in test data point [True]
# 36 Text feature [derived] present in test data point [True]
# 37 Text feature [3b] present in test data point [True]
# 43 Text feature [akt] present in test data point [True]
# 44 Text feature [2b] present in test data point [True]
# 46 Text feature [factor] present in test data point [True]
# 49 Text feature [presence] present in test data point [True]
# 51 Text feature [leukemia] present in test data point [True]
# 52 Text feature [receptors] present in test data point [True]
# 54 Text feature [oncogenic] present in test data point [True]
# 56 Text feature [inhibited] present in test data point [True]
# 57 Text feature [increase] present in test data point [True]
# 68 Text feature [enhanced] present in test data point [True]
# 71 Text feature [regulated] present in test data point [True]
# 73 Text feature [signaling] present in test data point [True]
# 76 Text feature [overexpression] present in test data point [True]
# 77 Text feature [phosphorylated] present in test data point [True]
# 79 Text feature [2a] present in test data point [True]
# 82 Text feature [amplification] present in test data point [True]
# 84 Text feature [cultured] present in test data point [True]
# 88 Text feature [concentrations] present in test data point [True]
# 92 Text feature [pathways] present in test data point [True]
# 94 Text feature [phosphorylation] present in test data point [True]
# 95 Text feature [absence] present in test data point [True]
# 96 Text feature [approximately] present in test data point [True]
# 171 Text feature [extracellular] present in test data point [True]
# 173 Text feature [insertion] present in test data point [True]
# 176 Text feature [fold] present in test data point [True]
# 177 Text feature [inhibitor] present in test data point [True]
# 178 Text feature [proliferation] present in test data point [True]
# 180 Text feature [ba] present in test data point [True]
# 181 Text feature [egfr] present in test data point [True]
# 182 Text feature [effective] present in test data point [True]
# 184 Text feature [years] present in test data point [True]
# 185 Text feature [f3] present in test data point [True]
# 186 Text feature [prior] present in test data point [True]
# 187 Text feature [stat3] present in test data point [True]
# 189 Text feature [stably] present in test data point [True]
# 192 Text feature [stimulation] present in test data point [True]
# 193 Text feature [growth] present in test data point [True]
# 195 Text feature [differentiation] present in test data point [True]
# 196 Text feature [conditions] present in test data point [True]
# 197 Text feature [high] present in test data point [True]
# 199 Text feature [positive] present in test data point [True]
# 200 Text feature [serum] present in test data point [True]
# 202 Text feature [size] present in test data point [True]
# 203 Text feature [examined] present in test data point [True]
# 264 Text feature [caused] present in test data point [True]
# 265 Text feature [24] present in test data point [True]
# 266 Text feature [numbers] present in test data point [True]
# 267 Text feature [elevated] present in test data point [True]
# 268 Text feature [cells] present in test data point [True]
# 273 Text feature [malignant] present in test data point [True]
# 276 Text feature [form] present in test data point [True]
# 278 Text feature [versus] present in test data point [True]
# 280 Text feature [mechanism] present in test data point [True]
# 281 Text feature [gain] present in test data point [True]
# 283 Text feature [use] present in test data point [True]
# 285 Text feature [suggest] present in test data point [True]
# 287 Text feature [contrast] present in test data point [True]
# 290 Text feature [000] present in test data point [True]
# 296 Text feature [either] present in test data point [True]
# 297 Text feature [cdna] present in test data point [True]
# 298 Text feature [tyrosine] present in test data point [True]
# 299 Text feature [fusion] present in test data point [True]
# 302 Text feature [added] present in test data point [True]
# 304 Text feature [membrane] present in test data point [True]
# 305 Text feature [level] present in test data point [True]
# 307 Text feature [incubated] present in test data point [True]
# 310 Text feature [without] present in test data point [True]
# 312 Text feature [reaction] present in test data point [True]
# 314 Text feature [constitutively] present in test data point [True]
# 315 Text feature [recently] present in test data point [True]
# 316 Text feature [myeloid] present in test data point [True]
# 317 Text feature [adenocarcinoma] present in test data point [True]
# 318 Text feature [domain] present in test data point [True]
# 321 Text feature [stem] present in test data point [True]
# 322 Text feature [nucleotide] present in test data point [True]
# 324 Text feature [mechanisms] present in test data point [True]
# 325 Text feature [gfp] present in test data point [True]
# 326 Text feature [previously] present in test data point [True]
# 332 Text feature [transcription] present in test data point [True]
# 334 Text feature [hours] present in test data point [True]
# 382 Text feature [pdgfr] present in test data point [True]
# 383 Text feature [total] present in test data point [True]
# 387 Text feature [pathway] present in test data point [True]
# 388 Text feature [induced] present in test data point [True]
# 389 Text feature [demonstrated] present in test data point [True]
# 390 Text feature [advanced] present in test data point [True]
# 391 Text feature [gists] present in test data point [True]
# 392 Text feature [molecule] present in test data point [True]
# 393 Text feature [phospho] present in test data point [True]
# 395 Text feature [chain] present in test data point [True]
# 396 Text feature [additional] present in test data point [True]
# 399 Text feature [increased] present in test data point [True]
# 401 Text feature [kit] present in test data point [True]
# 402 Text feature [showed] present in test data point [True]
# 403 Text feature [materials] present in test data point [True]
# 404 Text feature [12] present in test data point [True]
# 405 Text feature [potent] present in test data point [True]
# 406 Text feature [disease] present in test data point [True]
# 409 Text feature [probe] present in test data point [True]
# 411 Text feature [tumors] present in test data point [True]
# 413 Text feature [independent] present in test data point [True]
# 414 Text feature [university] present in test data point [True]
# 416 Text feature [carcinomas] present in test data point [True]
# 417 Text feature [regions] present in test data point [True]
# 418 Text feature [hr] present in test data point [True]
# 420 Text feature [50] present in test data point [True]
# 421 Text feature [strong] present in test data point [True]
# 426 Text feature [directly] present in test data point [True]
# 434 Text feature [specimens] present in test data point [True]
# 436 Text feature [genomic] present in test data point [True]
# 437 Text feature [possibility] present in test data point [True]
# 438 Text feature [signal] present in test data point [True]
# 439 Text feature [dependent] present in test data point [True]
# 441 Text feature [american] present in test data point [True]
# 443 Text feature [express] present in test data point [True]
# 444 Text feature [five] present in test data point [True]
# 445 Text feature [sensitivity] present in test data point [True]
# 447 Text feature [mutant] present in test data point [True]
# 449 Text feature [75] present in test data point [True]
# 450 Text feature [described] present in test data point [True]
# 451 Text feature [negative] present in test data point [True]
# 452 Text feature [alk] present in test data point [True]
# 457 Text feature [report] present in test data point [True]
# Out of the top  500  features  134 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------
warnings.filterwarnings("ignore")

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.2251235153585278
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.239147535893683
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.2043530108121028
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.2328467530796567
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2044986515393612
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.2221013862800063
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2040064786679165
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.2214734576928432
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.202729450070861
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.2171605722629721
# For values of best estimator =  2000 The train log loss is: 0.8378935962355536
# For values of best estimator =  2000 The cross validation log loss is: 1.202729450070861
# For values of best estimator =  2000 The test log loss is: 1.1392088979945851

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.2027294500708607
# Number of mis-classified points : 0.41729323308270677
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.4141 0.0066 0.0095 0.1037 0.3678 0.0834 0.0119 0.0021 0.0009]]
# Actual Class : 1
# --------------------------------------------------
# 3 Text feature [activation] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [phosphorylation] present in test data point [True]
# 10 Text feature [loss] present in test data point [True]
# 11 Text feature [constitutive] present in test data point [True]
# 12 Text feature [missense] present in test data point [True]
# 16 Text feature [signaling] present in test data point [True]
# 17 Text feature [brca1] present in test data point [True]
# 20 Text feature [pathogenic] present in test data point [True]
# 21 Text feature [yeast] present in test data point [True]
# 22 Text feature [deleterious] present in test data point [True]
# 23 Text feature [stability] present in test data point [True]
# 28 Text feature [protein] present in test data point [True]
# 31 Text feature [cells] present in test data point [True]
# 33 Text feature [variants] present in test data point [True]
# 38 Text feature [functional] present in test data point [True]
# 41 Text feature [neutral] present in test data point [True]
# 42 Text feature [expression] present in test data point [True]
# 44 Text feature [defective] present in test data point [True]
# 45 Text feature [proteins] present in test data point [True]
# 48 Text feature [cell] present in test data point [True]
# 51 Text feature [brct] present in test data point [True]
# 56 Text feature [ring] present in test data point [True]
# 58 Text feature [ovarian] present in test data point [True]
# 59 Text feature [response] present in test data point [True]
# 60 Text feature [predicted] present in test data point [True]
# 62 Text feature [patients] present in test data point [True]
# 66 Text feature [classified] present in test data point [True]
# 67 Text feature [repair] present in test data point [True]
# 73 Text feature [sensitivity] present in test data point [True]
# 76 Text feature [brca2] present in test data point [True]
# 77 Text feature [downstream] present in test data point [True]
# 78 Text feature [variant] present in test data point [True]
# 80 Text feature [clinical] present in test data point [True]
# 81 Text feature [expected] present in test data point [True]
# 82 Text feature [information] present in test data point [True]
# 85 Text feature [substitutions] present in test data point [True]
# 89 Text feature [activity] present in test data point [True]
# 90 Text feature [mammalian] present in test data point [True]
# 93 Text feature [use] present in test data point [True]
# 94 Text feature [type] present in test data point [True]
# 95 Text feature [sensitive] present in test data point [True]
# 97 Text feature [basis] present in test data point [True]
# 98 Text feature [history] present in test data point [True]
# Out of the top  100  features  44 are present in query point

# %% [markdown]
# <h4>4.5.3.2. Inorrectly Classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actuall Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0124 0.1724 0.0196 0.0142 0.0299 0.0256 0.7198 0.0053 0.0008]]
# Actuall Class : 5
# --------------------------------------------------
# 0 Text feature [kinase] present in test data point [True]
# 1 Text feature [activating] present in test data point [True]
# 3 Text feature [activation] present in test data point [True]
# 4 Text feature [inhibitors] present in test data point [True]
# 5 Text feature [tyrosine] present in test data point [True]
# 6 Text feature [function] present in test data point [True]
# 7 Text feature [phosphorylation] present in test data point [True]
# 8 Text feature [activated] present in test data point [True]
# 9 Text feature [treatment] present in test data point [True]
# 11 Text feature [constitutive] present in test data point [True]
# 12 Text feature [missense] present in test data point [True]
# 13 Text feature [oncogenic] present in test data point [True]
# 14 Text feature [growth] present in test data point [True]
# 15 Text feature [inhibitor] present in test data point [True]
# 16 Text feature [signaling] present in test data point [True]
# 19 Text feature [receptor] present in test data point [True]
# 24 Text feature [akt] present in test data point [True]
# 25 Text feature [constitutively] present in test data point [True]
# 27 Text feature [therapy] present in test data point [True]
# 28 Text feature [protein] present in test data point [True]
# 30 Text feature [therapeutic] present in test data point [True]
# 31 Text feature [cells] present in test data point [True]
# 35 Text feature [activate] present in test data point [True]
# 36 Text feature [drug] present in test data point [True]
# 37 Text feature [treated] present in test data point [True]
# 38 Text feature [functional] present in test data point [True]
# 40 Text feature [trials] present in test data point [True]
# 42 Text feature [expression] present in test data point [True]
# 45 Text feature [proteins] present in test data point [True]
# 46 Text feature [kinases] present in test data point [True]
# 48 Text feature [cell] present in test data point [True]
# 49 Text feature [inhibition] present in test data point [True]
# 50 Text feature [inhibited] present in test data point [True]
# 52 Text feature [resistance] present in test data point [True]
# 53 Text feature [f3] present in test data point [True]
# 54 Text feature [ba] present in test data point [True]
# 55 Text feature [extracellular] present in test data point [True]
# 59 Text feature [response] present in test data point [True]
# 62 Text feature [patients] present in test data point [True]
# 63 Text feature [imatinib] present in test data point [True]
# 69 Text feature [efficacy] present in test data point [True]
# 71 Text feature [survival] present in test data point [True]
# 72 Text feature [nsclc] present in test data point [True]
# 73 Text feature [sensitivity] present in test data point [True]
# 74 Text feature [proliferation] present in test data point [True]
# 77 Text feature [downstream] present in test data point [True]
# 79 Text feature [stimulation] present in test data point [True]
# 80 Text feature [clinical] present in test data point [True]
# 81 Text feature [expected] present in test data point [True]
# 82 Text feature [information] present in test data point [True]
# 83 Text feature [lines] present in test data point [True]
# 84 Text feature [dose] present in test data point [True]
# 85 Text feature [substitutions] present in test data point [True]
# 86 Text feature [egfr] present in test data point [True]
# 88 Text feature [advanced] present in test data point [True]
# 89 Text feature [activity] present in test data point [True]
# 92 Text feature [factor] present in test data point [True]
# 93 Text feature [use] present in test data point [True]
# 94 Text feature [type] present in test data point [True]
# 95 Text feature [sensitive] present in test data point [True]
# 97 Text feature [basis] present in test data point [True]
# Out of the top  100  features  61 are present in query point

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

warnings.filterwarnings("ignore")

clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid",cv=3)

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid",cv=3)


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid",cv=3)

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.07
# Support vector machines : Log Loss: 1.75
# Naive Bayes : Log Loss: 1.23
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 2.178
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 2.038
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.529
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.173
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.238
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.425

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 0.8140808683775697
# Log loss (CV) on the stacking classifier : 1.1727321777623931
# Log loss (test) on the stacking classifier : 1.0704388091381347
# Number of missclassified point : 0.34135338345864663
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 0.9540296522920536
# Log loss (CV) on the VotingClassifier : 1.1958953976249316
# Log loss (test) on the VotingClassifier : 1.1299376382566477
# Number of missclassified point : 0.3383458646616541
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# # 3. Apply Logistic regression with CountVectorizer Features, including both unigrams and bigrams

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer(ngram_range=(1,2))
train_gene_feature_onehotCoding_2 = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding_2 = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding_2= gene_vectorizer.transform(cv_df['Gene'])

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer(ngram_range=(1,2))
train_variation_feature_onehotCoding_2 = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding_2 = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding_2 = variation_vectorizer.transform(cv_df['Variation'])

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(min_df=3,ngram_range=(1,2))

train_text_feature_onehotCoding_2 = text_vectorizer.fit_transform(train_df['TEXT'])
# don't forget to normalize every feature
train_text_feature_onehotCoding_2 = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding_2 = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding_2 = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding_2 = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding_2 = normalize(cv_text_feature_onehotCoding, axis=0)

# %% [markdown]
# #### Feature Importance

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names_2(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer(ngram_range=(1,2))
    var_count_vec = CountVectorizer(ngram_range=(1,2))
    text_count_vec = CountVectorizer(min_df=3,ngram_range=(1,2))
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# ### Merging all the features

# %%
train_gene_var_onehotCoding_2 = hstack((train_gene_feature_onehotCoding_2,train_variation_feature_onehotCoding_2))
test_gene_var_onehotCoding_2 = hstack((test_gene_feature_onehotCoding_2,test_variation_feature_onehotCoding_2))
cv_gene_var_onehotCoding_2 = hstack((cv_gene_feature_onehotCoding_2,cv_variation_feature_onehotCoding_2))

train_x_onehotCoding_2 = hstack((train_gene_var_onehotCoding_2, train_text_feature_onehotCoding_2)).tocsr()
train_y_2 = np.array(list(train_df['Class']))

test_x_onehotCoding_2 = hstack((test_gene_var_onehotCoding_2, test_text_feature_onehotCoding_2)).tocsr()
test_y_2 = np.array(list(test_df['Class']))

cv_x_onehotCoding_2 = hstack((cv_gene_var_onehotCoding_2, cv_text_feature_onehotCoding_2)).tocsr()
cv_y_2 = np.array(list(cv_df['Class']))

# %% [markdown]
# ## 3.1 Logistic Regression

# %% [markdown]
# ### Hyper parameter Tuning

# %%
alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding_2, train_y_2)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
    sig_clf.fit(train_x_onehotCoding_2,train_y_2)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding_2)
    cv_log_error_array.append(log_loss(cv_y_2, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y_2, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_2, train_y_2)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid",cv=3)
sig_clf.fit(train_x_onehotCoding_2, train_y_2)

predict_y = sig_clf.predict_proba(train_x_onehotCoding_2)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding_2)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding_2)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.2365814807943456
# for alpha = 1e-05
# Log Loss : 1.1881291965275216
# for alpha = 0.0001
# Log Loss : 1.0773805272509
# for alpha = 0.001
# Log Loss : 1.0589488920965748
# for alpha = 0.01
# Log Loss : 1.231512399359321
# for alpha = 0.1
# Log Loss : 1.6182308051237169
# for alpha = 1
# Log Loss : 1.7375435136687665
# for alpha = 10
# Log Loss : 1.7521137152790136
# for alpha = 100
# Log Loss : 1.7537429475594732
# For values of best alpha =  0.001 The train log loss is: 0.7226360734182015
# For values of best alpha =  0.001 The cross validation log loss is: 1.0589488920965748
# For values of best alpha =  0.001 The test log loss is: 0.985114521881494

# %% [markdown]
# #### Testing the model with best hyper parameters

# %%
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding_2, train_y_2, cv_x_onehotCoding_2, cv_y_2, clf)
# Out:
# Log loss : 1.0589488920965748
# Number of mis-classified points : 0.37030075187969924
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ##### Correctly classified points

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding_2,train_y_2)
test_point_index = 2
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_2[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_2[test_point_index]),4))
print("Actual Class :", test_y_2[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_2(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[9.900e-03 2.520e-01 1.900e-03 9.100e-03 2.020e-02 7.700e-03 6.971e-01
#   2.000e-03 2.000e-04]]
# Actual Class : 7
# --------------------------------------------------
# Out of the top  500  features  0 are present in query point

# %% [markdown]
# ##### Incorrectly classified points

# %%
test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding_2[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding_2[test_point_index]),4))
print("Actual Class :", test_y_2[test_point_index])
indices = np.argsort(-clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names_2(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[1.360e-02 2.510e-02 3.320e-02 1.480e-02 2.610e-02 6.600e-03 8.771e-01
#   2.600e-03 8.000e-04]]
# Actual Class : 5
# --------------------------------------------------
# Out of the top  500  features  0 are present in query point

# %% [markdown]
# # Conclusions

# %%
# Please compare all your models using Prettytable library
# http://zetcode.com/python/prettytable/

from prettytable import PrettyTable
   
pt = PrettyTable()

pt.field_names = ["Model", "Train logloss", "CV logloss", "Test logloss","Misclassification rate"]

pt.add_row(["Naive Bayes", "0.80", "1.22", "1.11","0.40"])
pt.add_row(["KNN", "0.92", "1.19", "1.15","0.41"])
pt.add_row(["Logistic Regression(class balanced)", "0.80", "1.05", "0.98","0.37"])
pt.add_row(["Logistic Regression(NO class balance)", "0.57", "1.10", "1.00","0.36"])
pt.add_row(["Support vector machines", "0.77", "1.14", "1.05","0.38"])
pt.add_row(["Random Forest", "0.83", "1.20", "1.13","0.41"])
pt.add_row(["Stacking Model(LR+SVM+NB)", "0.81", "1.17", "1.07","0.34"])
pt.add_row(["Maximum voting Classifier", "0.95", "1.19", "1.12","0.33"])
pt.add_row(["", "", "", "",""])
pt.add_row(["Logistic Regression(unigrams,bigrams)", "0.72", "1.05", "0.98","0.37"])
pt.add_row(["Logistic Regression(NO class balance)", "0.57", "1.10", "1.00","0.36"])
print(pt)
# Out:
# +---------------------------------------+---------------+------------+--------------+------------------------+
# |                 Model                 | Train logloss | CV logloss | Test logloss | Misclassification rate |
# +---------------------------------------+---------------+------------+--------------+------------------------+
# |              Naive Bayes              |      0.80     |    1.22    |     1.11     |          0.40          |
# |                  KNN                  |      0.92     |    1.19    |     1.15     |          0.41          |
# |  Logistic Regression(class balanced)  |      0.80     |    1.05    |     0.98     |          0.37          |
# | Logistic Regression(NO class balance) |      0.57     |    1.10    |     1.00     |          0.36          |
# |        Support vector machines        |      0.77     |    1.14    |     1.05     |          0.38          |
# |             Random Forest             |      0.83     |    1.20    |     1.13     |          0.41          |
# |       Stacking Model(LR+SVM+NB)       |      0.81     |    1.17    |     1.07     |          0.34          |
# |       Maximum voting Classifier       |      0.95     |    1.19    |     1.12     |          0.33          |
# |                                       |               |            |              |                        |
# | Logistic Regression(unigrams,bigrams) |      0.72     |    1.05    |     0.98     |          0.37          |
# | Logistic Regression(NO class balance) |      0.57     |    1.10    |     1.00     |          0.36          |
# +---------------------------------------+---------------+------------+--------------+------------------------+
